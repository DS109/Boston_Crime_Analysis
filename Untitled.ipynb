# %%
import pandas as pd
import pandas_profiling
import numpy as np
from mpl_toolkits.basemap import Basemap

# %%
StreetLight = pd.read_csv('streetlight-locations.csv')
Property = pd.read_csv('property_assessment_2019.csv')

# %%
# profile = CrimeIncident.profile_report(title='Crime Profiling')
# profile.to_file(output_file="output.html")

# %%
StreetLight.head()
# Out:
#                                         the_geom  OBJECTID   TYPE        Lat  \
# 0    POINT (-71.0760443807948 42.35315925057316)         1  LIGHT  42.353159
# 1  POINT (-71.07538171240694 42.353347768071195)         2  LIGHT  42.353348
# 2   POINT (-71.07477488057383 42.35352052068278)         3  LIGHT  42.353521
# 3    POINT (-71.07440373484715 42.3535558201314)         4  LIGHT  42.353556
# 4   POINT (-71.07362079549182 42.35381056415504)         5  LIGHT  42.353811
#
#         Long
# 0 -71.076044
# 1 -71.075382
# 2 -71.074775
# 3 -71.074404
# 4 -71.073621

# %% [markdown]
#     We have three datasets available right now: Streetlight Locations, Property Assessment and Crime Incident Report.
#     For Streetlight Locations:
#
#     For Property Assessment:
#         The features we will use are 'position??' and 'AV_TOTAL'.
#
#
#     For Crime Incident Report data:
#         We decide to focus on the top 6 crimes(Larceny, Simple Assault, Vandalism, Other， Property Lost，Aggravated Assault) and the crimes that happened when there were stree lights on. To do that, we filter the raw data by selecting the corresponding crime and time. The rest of features we would like to use are 'Shooting', 'OCCURED_ON_DATE', 'DAY_OF_WEEK','LAT','LON'. For 'Shooting' feature, we made it 0 or 1 to indicate whether there has been a shooting place. Similarly, we made 'DAY_OF_WEEK' 0 or 1 to indicate whether the day is a weekday.
#
#     We first visualize the streelignt position to determine the appropriate mapping method.

# %% [markdown]
# Some insights of 'Crime Incident Report data'
#
#
# uszipcode, distance of light, Clean data: Null/missing data

# %%
######################## data_clean #######################

# %%
CrimeIncident = pd.read_csv("CrimeIncident.csv")
#CrimeIncident.groupby('OFFENSE_CODE_GROUP').size().sort_values(ascending = False)

# %%
# DELETE NULL and duplicates
CrimeIncident = CrimeIncident.drop_duplicates()
CrimeIncident = CrimeIncident[CrimeIncident['OFFENSE_CODE_GROUP'].notnull()]
CrimeIncident = CrimeIncident[CrimeIncident['Lat'].notnull()]
CrimeIncident = CrimeIncident[CrimeIncident['Long'].notnull()]
#CrimeIncident['OFFENSE_CODE_GROUP'].isnull().sum()

# %%
# INCIDENT_Number
delete_list=['INCIDENT_NUMBER','OFFENSE_CODE','OFFENSE_DESCRIPTION','DISTRICT','REPORTING_AREA','SHOOTING','UCR_PART','STREET','Location']
CrimeIncident.dtypes
# Out:
# INCIDENT_NUMBER         object
# OFFENSE_CODE             int64
# OFFENSE_CODE_GROUP      object
# OFFENSE_DESCRIPTION     object
# DISTRICT                object
# REPORTING_AREA          object
# SHOOTING                object
# OCCURRED_ON_DATE        object
# YEAR                     int64
# MONTH                    int64
# DAY_OF_WEEK             object
# HOUR                     int64
# UCR_PART                object
# STREET                  object
# Lat                    float64
# Long                   float64
# Location                object
# dtype: object

# %%
CrimeIncident['Lat'].isnull().sum()
# Out:
# 0

# %%
CrimeIncident['UCR_PART'].unique()
# Out:
# array(['Part One', 'Part Three', 'Part Two', 'Other', nan], dtype=object)

# %%
CrimeIncident
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 3           I192082859           724                       Auto Theft
# 4           I192082751           724                       Auto Theft
# 5           I192082680           727                       Auto Theft
# 6           I192082577           724                       Auto Theft
# 7           I192079582           727                       Auto Theft
# 8           I192078648          3114             Investigate Property
# 9           I192078647          3115               Investigate Person
# 10          I192078645          1402                        Vandalism
# 11          I192078645          3301                  Verbal Disputes
# 12          I192078642          3820  Motor Vehicle Accident Response
# 13          I192078640          3115               Investigate Person
# 14          I192078638          1402                        Vandalism
# 15          I192078638           423               Aggravated Assault
# 16          I192078637          3114             Investigate Property
# 17          I192078636           521             Residential Burglary
# 18          I192078635          3301                  Verbal Disputes
# 19          I192078633          3831  Motor Vehicle Accident Response
# 20          I192078632          3301                  Verbal Disputes
# 21          I192078628          3115               Investigate Person
# 22          I192078624          3301                  Verbal Disputes
# 23          I192078623          3802  Motor Vehicle Accident Response
# 24          I192078622           619                          Larceny
# 25          I192078621          1501               Firearm Violations
# 26          I192078619          3006               Medical Assistance
# 27          I192078615          3803  Motor Vehicle Accident Response
# 28          I192078613           423               Aggravated Assault
# 29          I192078613           802                   Simple Assault
# 30          I192078612          3114             Investigate Property
# 31          I192078611          1402                        Vandalism
# 32          I192078610          3501          Missing Person Reported
# ...                ...           ...                              ...
# 427164   I110261417-00          3125                  Warrant Arrests
# 427165   I110177502-00          3125                  Warrant Arrests
# 427168   I110177502-00           802                   Simple Assault
# 427170   I100636670-00          3125                  Warrant Arrests
# 427171   I100636670-00           629                          Larceny
# 427173   I100340225-00           339                          Robbery
# 427174   I100340225-00          3125                  Warrant Arrests
# 427178   I100222105-02          3125                  Warrant Arrests
# 427179   I100033064-00          2907                       Violations
# 427180   I100033064-00          2910                       Violations
# 427184   I090317057-00           403               Aggravated Assault
# 427185   I090317057-00          3125                  Warrant Arrests
# 427186   I080542626-00          1849                   Drug Violation
# 427187   I080542626-00          3125                  Warrant Arrests
# 427188   I080542626-00          1848                   Drug Violation
# 427190   I070720870-00           802                   Simple Assault
# 427192   I070720870-00          3125                  Warrant Arrests
# 427198   I070720870-00           637                          Larceny
# 427201   I060168073-00          3125                  Warrant Arrests
# 427202   I060168073-00          1864                   Drug Violation
# 427204   I050310906-00          3125                  Warrant Arrests
# 427205   I030217815-08          3125                  Warrant Arrests
# 427206   I030217815-08           111                         Homicide
# 427207   I020695506-00          1806                   Drug Violation
# 427208   I020695210-00          1843                   Drug Violation
# 427209   I020691165-00          3125                  Warrant Arrests
# 427210   I020674147-00          3125                  Warrant Arrests
# 427211   I020669075-00          3125                  Warrant Arrests
# 427212   I020662996-00          3125                  Warrant Arrests
# 427213   I010370257-00          3125                  Warrant Arrests
#
#                                    OFFENSE_DESCRIPTION DISTRICT  \
# 3                                           AUTO THEFT      E18
# 4                                           AUTO THEFT      E18
# 5                   AUTO THEFT - LEASED/RENTED VEHICLE      D14
# 6                                           AUTO THEFT       D4
# 7                   AUTO THEFT - LEASED/RENTED VEHICLE      A15
# 8                                 INVESTIGATE PROPERTY       B3
# 9                                   INVESTIGATE PERSON       A1
# 10                                           VANDALISM       B3
# 11                                      VERBAL DISPUTE       B3
# 12          M/V ACCIDENT INVOLVING PEDESTRIAN - INJURY       D4
# 13                                  INVESTIGATE PERSON       A7
# 14                                           VANDALISM       A1
# 15                                ASSAULT - AGGRAVATED       A1
# 16                                INVESTIGATE PROPERTY       E5
# 17                    BURGLARY - RESIDENTIAL - ATTEMPT       B2
# 18                                      VERBAL DISPUTE       B3
# 19               M/V - LEAVING SCENE - PROPERTY DAMAGE       B3
# 20                                      VERBAL DISPUTE       B3
# 21                                  INVESTIGATE PERSON       B2
# 22                                      VERBAL DISPUTE       B2
# 23                     M/V ACCIDENT - PROPERTY  DAMAGE      C11
# 24                                  LARCENY ALL OTHERS       C6
# 25       WEAPON - FIREARM - CARRYING / POSSESSING, ETC       B3
# 26                       SICK/INJURED/MEDICAL - PERSON       A1
# 27                      M/V ACCIDENT - PERSONAL INJURY       A7
# 28                                ASSAULT - AGGRAVATED       A7
# 29                            ASSAULT SIMPLE - BATTERY       A7
# 30                                INVESTIGATE PROPERTY      D14
# 31                                           VANDALISM      D14
# 32                                      MISSING PERSON       D4
# ...                                                ...      ...
# 427164                                  WARRANT ARREST       B2
# 427165                                  WARRANT ARREST       B2
# 427168                               ASSAULT & BATTERY       B2
# 427170                                  WARRANT ARREST       D4
# 427171                       LARCENY OTHER $50 TO $199       D4
# 427173                      ROBBERY - UNARMED - STREET       A1
# 427174                                  WARRANT ARREST       A1
# 427178                                  WARRANT ARREST      E13
# 427179                 VAL - OPERATING AFTER REV/SUSP.       B2
# 427180                 VAL - OPERATING AFTER REV/SUSP.       B2
# 427184                   ASSAULT & BATTERY D/W - OTHER       B3
# 427185                                  WARRANT ARREST       B3
# 427186            DRUGS - POSS CLASS B - COCAINE, ETC.       A1
# 427187                                  WARRANT ARREST       A1
# 427188  DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP       A1
# 427190                               ASSAULT & BATTERY       B2
# 427192                                  WARRANT ARREST       B2
# 427198                 LARCENY IN A BUILDING UNDER $50       B2
# 427201                                  WARRANT ARREST      E13
# 427202     DRUGS - POSS CLASS D - INTENT MFR DIST DISP      E13
# 427204                                  WARRANT ARREST       D4
# 427205                                  WARRANT ARREST      E18
# 427206             MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18
# 7       (42.38184582, -71.06655134)
# 8       (42.27796370, -71.09246318)
# 9       (42.36769032, -71.06586347)
# 10      (42.29181580, -71.07244098)
# 11      (42.29181580, -71.07244098)
# 12      (42.33241896, -71.07501315)
# 13      (42.37339168, -71.03647779)
# 14      (42.36433126, -71.06319318)
# 15      (42.36433126, -71.06319318)
# 16      (42.28861715, -71.12579957)
# 17      (42.31462973, -71.09261520)
# 18      (42.28362830, -71.09349553)
# 19      (42.28757867, -71.07527310)
# 20      (42.28576510, -71.08763245)
# 21      (42.31193478, -71.07341982)
# 22      (42.31785924, -71.08103560)
# 23      (42.28606484, -71.07001038)
# 24      (42.34006986, -71.05279420)
# 25      (42.27967492, -71.08381263)
# 26      (42.35594239, -71.06258333)
# 27      (42.38258915, -71.03341969)
# 28      (42.37912370, -71.02808210)
# 29      (42.37912370, -71.02808210)
# 30      (42.35272466, -71.12927406)
# 31      (42.33840140, -71.15158388)
# 32      (42.34403563, -71.08117746)
# ...                             ...
# 427164  (42.30703835, -71.06615319)
# 427165  (42.31127726, -71.08909334)
# 427168  (42.31127726, -71.08909334)
# 427170  (42.33695098, -71.08574813)
# 427171  (42.33695098, -71.08574813)
# 427173  (42.36164502, -71.06229949)
# 427174  (42.36164502, -71.06229949)
# 427178  (42.31362799, -71.09560307)
# 427179  (42.32177032, -71.09779774)
# 427180  (42.32177032, -71.09779774)
# 427184  (42.30189690, -71.08554944)
# 427185  (42.30189690, -71.08554944)
# 427186  (42.35231190, -71.06370510)
# 427187  (42.35231190, -71.06370510)
# 427188  (42.35231190, -71.06370510)
# 427190  (42.30956305, -71.08990197)
# 427192  (42.30956305, -71.08990197)
# 427198  (42.30956305, -71.08990197)
# 427201  (42.32283759, -71.10096723)
# 427202  (42.32283759, -71.10096723)
# 427204  (42.33695098, -71.08574813)
# 427205  (42.25592648, -71.12317207)
# 427206  (42.25592648, -71.12317207)
# 427207  (42.36183857, -71.05976489)
# 427208  (42.36183857, -71.05976489)
# 427209  (42.36183857, -71.05976489)
# 427210  (42.36183857, -71.05976489)
# 427211  (42.36183857, -71.05976489)
# 427212  (42.36183857, -71.05976489)
# 427213  (42.30233307, -71.11156487)
#
# [398916 rows x 17 columns]

# %%
######################## data_clean #######################

# %%
Property = pd.read_csv('property_assessment_2019.csv')
## Replace NULL with ""
Property['ST_NAME_SUF'].fillna("",inplace= True)
Property = Property[Property['ZIPCODE'].notnull()]
Property['ZIPCODE'] = Property['ZIPCODE'].astype(np.int64)

# %%
Property.dtypes
# Out:
# PID                  int64
# CM_ID              float64
# GIS_ID               int64
# ST_NUM              object
# ST_NAME             object
# ST_NAME_SUF         object
# UNIT_NUM            object
# ZIPCODE              int64
# PTYPE                int64
# LU                  object
# OWN_OCC             object
# OWNER               object
# MAIL_ADDRESSEE      object
# MAIL_ADDRESS        object
# MAIL CS             object
# MAIL_ZIPCODE        object
# AV_LAND              int64
# AV_BLDG              int64
# AV_TOTAL             int64
# GROSS_TAX            int64
# LAND_SF            float64
# YR_BUILT           float64
# YR_REMOD           float64
# GROSS_AREA         float64
# LIVING_AREA        float64
# NUM_FLOORS         float64
# STRUCTURE_CLASS     object
# R_BLDG_STYL         object
# R_ROOF_TYP          object
# R_EXT_FIN           object
#                     ...
# R_OVRALL_CND        object
# R_INT_CND           object
# R_INT_FIN           object
# R_VIEW              object
# S_NUM_BLDG         float64
# S_BLDG_STYL         object
# S_UNIT_RES         float64
# S_UNIT_COM         float64
# S_UNIT_RC          float64
# S_EXT_FIN           object
# S_EXT_CND           object
# U_BASE_FLOOR       float64
# U_NUM_PARK         float64
# U_CORNER            object
# U_ORIENT            object
# U_TOT_RMS           object
# U_BDRMS            float64
# U_FULL_BTH         float64
# U_HALF_BTH         float64
# U_BTH_STYLE         object
# U_BTH_STYLE2        object
# U_BTH_STYLE3        object
# U_KITCH_TYPE        object
# U_KITCH_STYLE       object
# U_HEAT_TYP          object
# U_AC                object
# U_FPLACE           float64
# U_INT_FIN           object
# U_INT_CND           object
# U_VIEW              object
# Length: 75, dtype: object

# %%
delete_list = ['PID', 'CM_ID', 'GIS_ID',
       'UNIT_NUM', 'PTYPE', 'LU', 'OWN_OCC', 'OWNER',
       'MAIL_ADDRESSEE', 'MAIL_ADDRESS', 'MAIL CS', 'MAIL_ZIPCODE', 'AV_LAND',
       'AV_BLDG', 'GROSS_TAX', 'LAND_SF', 'YR_BUILT', 'YR_REMOD',
       'GROSS_AREA', 'LIVING_AREA', 'NUM_FLOORS', 'STRUCTURE_CLASS',
       'R_BLDG_STYL', 'R_ROOF_TYP', 'R_EXT_FIN', 'R_TOTAL_RMS', 'R_BDRMS',
       'R_FULL_BTH', 'R_HALF_BTH', 'R_BTH_STYLE', 'R_BTH_STYLE2',
       'R_BTH_STYLE3', 'R_KITCH', 'R_KITCH_STYLE', 'R_KITCH_STYLE2',
       'R_KITCH_STYLE3', 'R_HEAT_TYP', 'R_AC', 'R_FPLACE', 'R_EXT_CND',
       'R_OVRALL_CND', 'R_INT_CND', 'R_INT_FIN', 'R_VIEW', 'S_NUM_BLDG',
       'S_BLDG_STYL', 'S_UNIT_RES', 'S_UNIT_COM', 'S_UNIT_RC', 'S_EXT_FIN',
       'S_EXT_CND', 'U_BASE_FLOOR', 'U_NUM_PARK', 'U_CORNER', 'U_ORIENT',
       'U_TOT_RMS', 'U_BDRMS', 'U_FULL_BTH', 'U_HALF_BTH', 'U_BTH_STYLE',
       'U_BTH_STYLE2', 'U_BTH_STYLE3', 'U_KITCH_TYPE', 'U_KITCH_STYLE',
       'U_HEAT_TYP', 'U_AC', 'U_FPLACE', 'U_INT_FIN', 'U_INT_CND', 'U_VIEW']
# ST_NUM ST_NAME ST_NAME_SUF, ZIPCODE,'AV_TOTAL'
